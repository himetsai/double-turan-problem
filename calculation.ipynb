# %%
var("a, b, c, n, k")

f = binomial(a + c, 2) - binomial(b + c, 2) - 2 * (floor((c + 2)^2 / 4) - floor(c^2 / 4))

f.simplify_full()
# Out:
# 1/2*a^2 - 1/2*b^2 + (a - b)*c - 1/2*a + 1/2*b + 2*floor(1/4*c^2) - 2*floor(1/4*c^2 + c) - 2

# %%
g = (binomial((1 - k) * n / 2, 2) - binomial(k * n, 2))

g.simplify_full()
# Out:
# -1/8*(3*k^2 + 2*k - 1)*n^2 + 1/4*(3*k - 1)*n

# %%
plot(g.subs(n = 10000), (k, 0, 1/2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g.subs(k = 0)
# Out:
# 1/8*(n - 2)*n
